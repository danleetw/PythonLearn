# %% [markdown]
# # 周莫烦
# https://www.youtube.com/watch?v=eXOQwzHsyqU&list=PLXO45tsB95cJU56K4EtkG0YNGBZCuDwAH

# %%
import tkinter as tk
from tkinter import Tk, Entry, mainloop, StringVar

# %% [markdown]
# # button
#
# win=tk.Tk()
# win.title("新視窗")
# win.geometry("400x100")
# var=tk.StringVar()
#
# l=tk.Label(win,textvariable=var,bg="green",width=15,height=2)
# l.pack()
#
# on_hit=False
# def hit_me():
#     global on_hit
#     if on_hit==False:
#         on_hit=True
#         var.set("You hit me!")
#     else:
#         on_hit=False
#         var.set("")
#
#
#
# btn=tk.Button(win,text="button",command=hit_me)
# #btn.pack()
# btn.pack()
# win.mainloop()

# %% [markdown]
# # button,text
# win1=tk.Tk()
# win1.title("新視窗1")
# win1.geometry("400x200")
#
#
# #e=tk.Entry(win1,show='*')
# #e=tk.Entry(win1,show=None)
# e=tk.Entry(win1,show='a')
# e.pack()
#
# t=tk.Text(win1,height=2)
# t.pack()
#
# var=tk.StringVar()
#
#
#
#
# on_hit=False
# def hit_me1():
#     global on_hit
#     if on_hit==False:
#         on_hit=True
#         var.set("You hit me!")
#     else:
#         on_hit=False
#         var.set("")
#
# def insert_point():
#     var = e.get()
#     t.insert('insert',var)
# def insert_end():
#     var = e.get()
#     t.insert(1.1,var)
#
#
# btn1=tk.Button(win1,text="Insert Porint",command=insert_point)
# btn2=tk.Button(win1,text="Insert End",command=insert_end)
# #btn.pack()
# btn1.pack()
# btn2.pack()
#
# l1=tk.Label(win1,textvariable=var,bg="green",width=15,height=2)
# l1.pack()
# win1.mainloop()

# %% [markdown]
# # List Box
# win1=tk.Tk()
# win1.title("新視窗List Box")
# win1.geometry("400x200")
#
# var1=tk.StringVar()
# l=tk.Label(win1,bg='yellow',width=4,textvariable=var1)
# l.pack()
#
# def print_selection():
#     value=lb.get(lb.curselection())
#     var1.set(value)
#
# b1=tk.Button(win1,text='Print Selection',command=print_selection)
# b1.pack()
#
# var2=tk.StringVar()
# var2.set((11,22,33,44))
# lb=tk.Listbox(win1,listvariable=var2,height=5)
# lb.pack()
#
# list_items=['Dan','steven','Kevin Wang','DT Chen','Jhon chang']
# for item in list_items:
#     lb.insert('end',item)
# lb.insert(1,'1---')
# lb.insert(2,'2----')
# #lb.select_set(len(var2.get())
# #print(var2.get)
#
# win1.mainloop()

# %% [markdown]
# # Radio Boox
# win=tk.Tk()
# win.title("新視窗RadioButton")
# win.geometry("400x200")
#
# var1=tk.StringVar()
#
# label1=tk.Label(win,bg='yellow',width=20,text='empty')
# label1.pack()
#
# def print_selection():
#     label1.config(text='You have selected ' + var1.get())
#
#
# radio_but1=tk.Radiobutton(win,text='Option A',
#                          variable=var1,value='A',
#                          command=print_selection)
# radio_but1.pack()
#
# radio_but2=tk.Radiobutton(win,text='Option B',
#                          variable=var1,value='B',
#                          command=print_selection)
# radio_but2.pack()
#
# radio_but3=tk.Radiobutton(win,text='Option C',
#                          variable=var1,value='C',
#                          command=print_selection)
# radio_but3.pack()
#
#
# win1.mainloop()

# %% [markdown]
# # scare
# win=tk.Tk()
# win.title("新視窗scale")
# win.geometry("400x200")
#
#
# label1=tk.Label(win,bg='yellow',width=20,text='empty')
# label1.pack()
#
# def print_selection(v):
#     label1.config(text='You have selected ' + v)
#
# scale1=tk.Scale(win,label='Try me',from_=5,to=11,orient=tk.HORIZONTAL,
#                 length=200,showvalue=1,tickinterval=3,resolution=0.01,command=print_selection)
# scale1.pack()
#
#
#
# win1.mainloop()

# %% [markdown]
# # check button
# win=tk.Tk()
# win.title("新視窗Checkbutton")
# win.geometry("400x200")
#
#
# label1=tk.Label(win,bg='yellow',width=20,text='empty')
# label1.pack()
#
# def print_selection():
#     label1.config(text='You have selected '+
#                   str(var1.get()) + str(var2.get()) )
#
# var1=tk.IntVar()
# var2=tk.IntVar()
# chkbut1=tk.Checkbutton(win,text='Python',variable=var1,
#                       onvalue=1,offvalue=0,command=print_selection)
# chkbut2=tk.Checkbutton(win,text='C++',variable=var2,
#                      onvalue=1,offvalue=0,command=print_selection)
# chkbut1.pack()
# chkbut2.pack()
#
#
# win1.mainloop()

# %% [markdown]
# # canvas
# win=tk.Tk()
# win.title("新視窗Canvas")
# win.geometry("400x200")
#
#
# canvas1=tk.Canvas(win,bg='blue',height=100,width=200)
# #image_file=tk.PhotoImage(file='home.gif')
# #image_file=tk.PhotoImage(file='ball.jpg')
# #線
# line=canvas1.create_line(50,50,80,80)
# #圓形
# oval=canvas1.create_oval(50,50,80,80,fill='red')
# #扇形
# arc=canvas1.create_arc(80,80,110,110,start=0,extent=180)
# #矩形
# rect=canvas1.create_rectangle(100,30,100+20,30+20)
#
#
# canvas1.pack()
#
#
#
# def moveit():
#     canvas1.move(rect,0,2)
#
# but1=tk.Button(win,text="Move",command=moveit).pack()
#
# #image=canvas1.create_image(10,10,anchor='nw',image=image_file)
#
#
# win.mainloop()

# %%
import tkinter
root = tkinter.Tk(  )
for r in range(3):
   for c in range(4):
      tkinter.Label(root, text='R%s/C%s'%(r,c),
         borderwidth=1 ).grid(row=r,column=c)
root.mainloop(  )

# %%
from tkinter import *

root = Tk()

height = 5
width = 5
for i in range(height): #Rows
    for j in range(width): #Columns
        b = Entry(root, text="")
        b.grid(row=i, column=j)

mainloop()

# %%
from tkinter import *
import csv
from tables import createStandardTable as cst

window = Tk()

#Your file can contain any number of rows and columns so long as they
#are even of course. Make sure you rename the films to the name of your file
f = open("films.csv")

#note here I have sent it root but you can also send it a frame
#see using tables with frames
#It actually returns a frame that will be placed on the window or frame
#you send
newtable = cst(f,window)

newtable.grid()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-20-fd65212a44a2> in <module>
#       1 from tkinter import *
#       2 import csv
# ----> 3 from tables import createStandardTable as cst
#       4
#       5 window = Tk()
#
# ImportError: cannot import name 'createStandardTable'
