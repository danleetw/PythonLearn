# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# D:\Anaconda\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
import random
plot(range(1,100),[random.randint(1,53) for i in range(1,100)])

# %%
# %ls
# Out:
#  磁碟區 D 中的磁碟是 LENOVO
#  磁碟區序號:  82B4-F011
#
#  d:\danlee\Python_WorkSpace 的目錄
#
# 2018/10/10  上午 07:51    <DIR>          .
# 2018/10/10  上午 07:51    <DIR>          ..
# 2018/10/10  上午 07:47    <DIR>          .ipynb_checkpoints
# 2018/09/01  下午 10:57    <DIR>          .metadata
# 2018/10/10  上午 07:51            20,058 sample1.ipynb
# 2018/09/01  下午 11:56    <DIR>          test
# 2018/10/10  上午 07:49               555 Untitled.ipynb
# 2018/10/10  上午 07:48                72 Untitled1.ipynb
#                3 個檔案          20,685 位元組
#                5 個目錄   5,606,789,120 位元組可用

# %%
from IPython.display import display,Math,Latex
display(Math(r'c = \sqrt{a^2+b^2}'))
# Out:
# $$c = \sqrt{a^2+b^2}$$
