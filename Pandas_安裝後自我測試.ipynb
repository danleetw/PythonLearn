# %%
import pandas as pd
pd.test()
# Out:
# running: pytest --skip-slow --skip-network D:\Anaconda\lib\site-packages\pandas
# ============================= test session starts =============================
# platform win32 -- Python 3.6.6, pytest-3.8.2, py-1.6.0, pluggy-0.7.1
# rootdir: D:\, inifile:
# plugins: remotedata-0.3.0, openfiles-0.3.0, doctestplus-0.1.3, arraydiff-0.2
# collected 26759 items / 2 skipped
#
# ..\..\Anaconda\lib\site-packages\pandas\tests\test_algos.py ............ [  0%]
# ..............................................X......................... [  0%]
# ............................                                             [  0%]
# ..\..\Anaconda\lib\site-packages\pandas\tests\test_base.py ............. [  0%]
# ........................................................................ [  0%]
# ........................................................................ [  1%]
# .........................................x                               [  1%]
# ...

# %%
import numpy as np

# %% [markdown]
# https://dotblogs.com.tw/kevinya/2018/06/04/124135
